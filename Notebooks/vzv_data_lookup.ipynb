# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('dot_VZV_Speed_Limits_20190604.csv')
# Out:
#        postvz_sg                         street  postvz_sl  \
# 0             NO                      WEST ROAD         25
# 1             NO  HARLEM RIVER DRIVE EXIT 20 SB          0
# 2             NO  HARLEM RIVER DRIVE EXIT 20 SB          0
# 3            YES          GRAND CENTRAL PARKWAY         50
# 4            YES          GRAND CENTRAL PARKWAY         50
# 5            YES          GRAND CENTRAL PARKWAY         50
# 6            YES          GRAND CENTRAL PARKWAY         50
# 7            YES        JACKIE ROBINSON PARKWAY         45
# 8            YES        JACKIE ROBINSON PARKWAY         45
# 9            YES        JACKIE ROBINSON PARKWAY         45
# 10           YES        JACKIE ROBINSON PARKWAY         45
# 11           YES        JACKIE ROBINSON PARKWAY         45
# 12           YES        JACKIE ROBINSON PARKWAY         45
# 13           YES            VAN WYCK EXPRESSWAY         50
# 14           YES            VAN WYCK EXPRESSWAY         50
# ...

# %%
hump_df = pd.read_csv('dot_VZV_Speed_Humps_20190604.csv')
print(len(hump_df))
hump_df.head()
# Out:
# 2962
#         on_st                                           the_geom  \
# 0    1 STREET  MULTILINESTRING ((-73.9799168591299 40.6728580...
# 1    1 STREET  MULTILINESTRING ((-73.99294738655144 40.678995...
# 2  100 AVENUE  MULTILINESTRING ((-73.73560306475389 40.714945...
# 3      100 ST  MULTILINESTRING ((-74.03364741744534 40.612833...
# 4  100 Street  MULTILINESTRING ((-73.86848374851515 40.757334...
#
#               to_st             from_st  new_humps  \
# 0          7 AVENUE            6 AVENUE          2
# 1       BOND STREET         HOYT STREET          2
# 2   SPRINGFIELD BL.  100 DR./220 STREET          1
# 3  FT HAMILTON PKWY          FOURTH AVE          1
# 4       34TH Avenue  Northern Boulevard          1
#
#                      date_insta  Shape_Leng
# 0  05/22/2014 12:00:00 AM +0000  775.659477
# 1  09/11/2017 12:00:00 AM +0000  652.150192
# 2  12/15/2011 12:00:00 AM +0000  423.930065
# 3  08/01/1996 12:00:00 AM +0000  591.886182
# ...

# %%
art_slowzone_df = pd.read_csv('dot_VZV_Arterial_Slow_Zones_20190604.csv')
print(len(art_slowzone_df))
art_slowzone_df.head()
# Out:
# 28
#     FROM_STREE                    ENFORCEMEN        TO_STREET  \
# 0  Columbia St  05/19/2014 12:00:00 AM +0000            76 St
# 1   E 140th St  05/19/2014 12:00:00 AM +0000  Mosholu Parkway
# 2        40 Rd  06/02/2014 12:00:00 AM +0000           114 St
# 3   Freeman St  06/02/2014 12:00:00 AM +0000        Bayard St
# 4   Jerome Ave  06/09/2014 12:00:00 AM +0000      NE Thrwy SB
#
#                                             the_geom    Shape_Leng
# 0  MULTILINESTRING ((-73.89867564098704 40.675582...  80344.034362
# 1  MULTILINESTRING ((-73.92988099693609 40.813040...  76627.888146
# 2  MULTILINESTRING ((-73.93474259188893 40.750979...  22288.089025
# 3  MULTILINESTRING ((-73.94499614744701 40.720773...  11108.542243
# 4  MULTILINESTRING ((-73.881244225275 40.88270963...  15702.229781

# %%
pedestrian_int_df = pd.read_csv('dot_VZV_Leading_Pedestrian_Intervals_20190604.csv')
print(len(pedestrian_int_df))
pedestrian_int_df.head()
# Out:
# 3530
#            MainStreet                                       the_geom  \
# 0     Clarkson Avenue  POINT (-73.92178687247512 40.660030540821886)
# 1  Westchester Avenue   POINT (-73.84806112901038 40.83563735481106)
# 2           64 Avenue   POINT (-73.75889535426067 40.74648170660847)
# 3            8 Avenue   POINT (-73.98122431377725 40.66334658903114)
# 4            8 Avenue   POINT (-73.98172910518181 40.66274281927975)
#
#                      Install_Da     CrossStree       LONG        LAT
# 0  03/28/2019 12:00:00 AM +0000    E 95 Street -73.921787  40.660031
# 1  03/26/2019 12:00:00 AM +0000  Glover Street -73.848061  40.835637
# 2  04/05/2019 12:00:00 AM +0000     218 Street -73.758895  40.746482
# 3  04/08/2019 12:00:00 AM +0000      13 Street -73.981224  40.663347
# 4  04/08/2019 12:00:00 AM +0000      14 Street -73.981729  40.662743

# %%
enhanced_x_ing_df = pd.read_csv('dot_VZV_Enhanced_Crossings_20190604.csv')
print(len(enhanced_x_ing_df))
enhanced_x_ing_df.head()
# Out:
# 164
#          LAT                    Date_Imple  \
# 0  40.796090  04/01/1990 12:00:00 AM +0000
# 1  40.796720  04/01/1990 12:00:00 AM +0000
# 2  40.840177  09/09/2013 12:00:00 AM +0000
# 3  40.838483  09/09/2013 12:00:00 AM +0000
# 4  40.876601  07/31/2013 12:00:00 AM +0000
#
#                                         the_geom       LONG
# 0   POINT (-73.96334961527361 40.79608997359387) -73.963350
# 1  POINT (-73.96288578055824 40.796720248848196) -73.962886
# 2    POINT (-73.8955129567713 40.84017709765643) -73.895513
# 3   POINT (-73.89663238458259 40.83848257432714) -73.896632
# 4   POINT (-73.87654462710819 40.87660093881003) -73.876545

# %%
neighbor_slowzone_df = pd.read_csv('dot_VZV_Neighborhood_Slow_Zones_20190604.csv')
print(len(neighbor_slowzone_df))
neighbor_slowzone_df
# Out:
# 28
#                                      Name  Year  \
# 0             New Brighton / St George SZ  2012
# 1                               Corona SZ  2012
# 2        Jackson Heights/East Elmhurst SZ  2013
# 3                             Elmhurst SZ  2013
# 4                           Auburndale SZ  2013
# 5                               Inwood SZ  2012
# 6                           Baychester SZ  2013
# 7                         Dongan Hills SZ  2013
# 8                          Eastchester SZ  2013
# 9                            Riverdale SZ  2013
# 10                            Rosebank SZ  2013
# 11                             MT Eden SZ  2012
# 12                         Boerum Hill SZ  2013
# 13                           Claremont SZ  2011
# 14                            X10 Norwood  2014
# 15  Alphabet City Tompkins Square Park SZ  2014
# 16                        Clinton Hill SZ  2014
# 17                     Jackson Heights SZ  2014
# ...

# %%
signal_timing_df = pd.read_csv('dot_VZV_Signal_Timing_20190604.csv')
print(len(signal_timing_df))
signal_timing_df.head()
# Out:
# 206
#                                             the_geom         FromStreet  \
# 0  MULTILINESTRING ((-73.9886393747839 40.7229337...  E. Houston Street
# 1  MULTILINESTRING ((-74.01003536651845 40.738686...        West Street
# 2  MULTILINESTRING ((-73.99434657981533 40.639816...  Bay Ridge Parkway
# 3  MULTILINESTRING ((-73.99489176193522 40.625461...          37 Street
# 4  MULTILINESTRING ((-73.97968252687272 40.636639...          39 Street
#
#           ToStreet   OnStreet    YR    Shape_Leng
# 0       125 Street   1 Avenue  2018  32803.553583
# 1        59 Street  10 Avenue  2018  13159.609046
# 2  New Utrecht Ave  11 Avenue  2018   7827.081913
# 3        86 Street  15 Avenue  2018  12871.028660
# 4        86 Street  16 Avenue  2018  12348.608019

# %%
left_turn_calming_df = pd.read_csv('dot_VZV_Left_Turn_Traffic_Calming_20190604.csv')
print(len(left_turn_calming_df))
left_turn_calming_df.head()
# Out:
# 217
#           street2      street1                                treatment_  \
# 0  CASTLE HILL AV  STARLING AV                     Qucik Kurb to Stopbar
# 1          169 ST   JAMAICA AV                      Quick Kurb to X-walk
# 2         E 25 ST         2 AV  Bike Island Channelization & Delineators
# 3   FRESH POND RD    MYRTLE AV                     Quick Kurb to stopbar
# 4         E 57 ST         3 AV                      Quick Kurb to X-walk
#
#                                         the_geom  \
# 0   POINT (-73.8522072103496 40.836347495850546)
# 1   POINT (-73.7907959320156 40.706869789970746)
# 2   POINT (-73.97996739875398 40.73916829106897)
# 3   POINT (-73.89457448987582 40.70079805781446)
# 4  POINT (-73.96746215121291 40.760222905807986)
#
#                      completion             x              y       LONG  \
# 0  12/13/2017 12:00:00 AM +0000  1.025146e+06  244015.767596 -73.852207
# 1  12/09/2017 12:00:00 AM +0000  1.042252e+06  196877.470796 -73.790796
# ...
